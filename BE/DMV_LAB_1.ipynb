# %%
'''
Data Loading, Storage and File Formats
Problem Statement: Analyzing Sales Data from Multiple File Formats
Dataset: Sales data in multiple file formats (e.g., CSV, Excel, JSON)
Description: The goal is to load and analyze sales data from different file formats, including 
CSV, Excel, and JSON, and perform data cleaning, transformation, and analysis on the 
dataset.
Tasks to Perform:
Obtain sales data files in various formats, such as CSV, Excel, and JSON.
1. Load the sales data from each file format into the appropriate data structures or 
dataframes.
2. Explore the structure and content of the loaded data, identifying any inconsistencies, 
missing values, or data quality issues.
3. Perform data cleaning operations, such as handling missing values, removing 
duplicates, or correcting inconsistencies.
4. Convert the data into a unified format, such as a common dataframe or data structure, 
to enable seamless analysis.
5. Perform data transformation tasks, such as merging multiple datasets, splitting 
columns, or deriving new variables.
6. Analyze the sales data by performing descriptive statistics, aggregating data by 
specific variables, or calculating metrics such as total sales, average order value, or 
product category distribution.
7. Create visualizations, such as bar plots, pie charts, or box plots, to represent the sales 
data and gain insights into sales trends, customer behavior, or product performance.
'''
None

# %%
import pandas as pd

# %%
# 1. Load the sales data from each file format into the appropriate data structures or 
# dataframes.
data = pd.read_csv('sales-data-sample.csv')
data
# Out:
#                      OrderDate         Category           City        Country  \
# 0     2011-01-04T00:00:00.000Z  Office Supplies        Houston  United States
# 1     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 2     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 3     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 4     2011-01-06T00:00:00.000Z  Office Supplies   Philadelphia  United States
# ...                        ...              ...            ...            ...
# 9989  2014-12-31T00:00:00.000Z  Office Supplies      Fairfield  United States
# 9990  2014-12-31T00:00:00.000Z  Office Supplies      Fairfield  United States
# 9991  2014-12-31T00:00:00.000Z  Office Supplies       Loveland  United States
# 9992  2014-12-31T00:00:00.000Z  Office Supplies  New York City  United States
# 9993  2014-12-31T00:00:00.000Z       Technology  New York City  United States
#
# ...

# %%
# 2. Explore the structure and content of the loaded data, identifying any inconsistencies, 
# missing values, or data quality issues.
# 3. Perform data cleaning operations, such as handling missing values, removing 
# duplicates, or correcting inconsistencies.
data.isnull().sum()
# Out:
# OrderDate                 0
# Category                  0
# City                      0
# Country                   0
# CustomerName              0
# Discount                  0
# OrderID                   0
# PostalCode                0
# ProductName               0
# Profit                    0
# Quantity                  0
# Region                    0
# Sales                     0
# Segment                   0
# ShipDate                  0
# ShipMode                  0
# State                     0
# Sub_Category              0
# DaystoShipActual          0
# SalesForecast             0
# ShipStatus                0
# DaystoShipScheduled       0
# OrderProfitable        9994
# SalesperCustomer          0
# ProfitRatio               0
# SalesaboveTarget       9994
# latitude                  0
# longitude                 0
# dtype: int64

# %%
data = data.drop(columns=['OrderProfitable','SalesaboveTarget'])

# %%
data.isnull().sum()
# Out:
# OrderDate              0
# Category               0
# City                   0
# Country                0
# CustomerName           0
# Discount               0
# OrderID                0
# PostalCode             0
# ProductName            0
# Profit                 0
# Quantity               0
# Region                 0
# Sales                  0
# Segment                0
# ShipDate               0
# ShipMode               0
# State                  0
# Sub_Category           0
# DaystoShipActual       0
# SalesForecast          0
# ShipStatus             0
# DaystoShipScheduled    0
# SalesperCustomer       0
# ProfitRatio            0
# latitude               0
# longitude              0
# dtype: int64

# %%
data = data.drop_duplicates()
data
# Out:
#                      OrderDate         Category           City        Country  \
# 0     2011-01-04T00:00:00.000Z  Office Supplies        Houston  United States
# 1     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 2     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 3     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 4     2011-01-06T00:00:00.000Z  Office Supplies   Philadelphia  United States
# ...                        ...              ...            ...            ...
# 9989  2014-12-31T00:00:00.000Z  Office Supplies      Fairfield  United States
# 9990  2014-12-31T00:00:00.000Z  Office Supplies      Fairfield  United States
# 9991  2014-12-31T00:00:00.000Z  Office Supplies       Loveland  United States
# 9992  2014-12-31T00:00:00.000Z  Office Supplies  New York City  United States
# 9993  2014-12-31T00:00:00.000Z       Technology  New York City  United States
#
# ...

# %%
data.loc[:, 'order_value'] = data['Quantity'] * data['Sales']
data
# Out:
#                      OrderDate         Category           City        Country  \
# 0     2011-01-04T00:00:00.000Z  Office Supplies        Houston  United States
# 1     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 2     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 3     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 4     2011-01-06T00:00:00.000Z  Office Supplies   Philadelphia  United States
# ...                        ...              ...            ...            ...
# 9989  2014-12-31T00:00:00.000Z  Office Supplies      Fairfield  United States
# 9990  2014-12-31T00:00:00.000Z  Office Supplies      Fairfield  United States
# 9991  2014-12-31T00:00:00.000Z  Office Supplies       Loveland  United States
# 9992  2014-12-31T00:00:00.000Z  Office Supplies  New York City  United States
# 9993  2014-12-31T00:00:00.000Z       Technology  New York City  United States
#
# ...

# %%
data.describe()
# Out:
#           Discount    PostalCode       Profit     Quantity         Sales  \
# count  9993.000000   9993.000000  9993.000000  9993.000000   9993.000000
# mean      0.156188  55191.576403    28.655959     3.789753    229.868208
# std       0.206457  32065.074478   234.267081     2.225149    623.279922
# min       0.000000   1040.000000 -6600.000000     1.000000      0.000000
# 25%       0.000000  23223.000000     2.000000     2.000000     17.000000
# 50%       0.200000  56560.000000     9.000000     3.000000     54.000000
# 75%       0.200000  90008.000000    29.000000     5.000000    210.000000
# max       0.800000  99301.000000  8400.000000    14.000000  22638.000000
#
#        DaystoShipActual  SalesForecast  DaystoShipScheduled  SalesperCustomer  \
# count       9993.000000    9993.000000          9993.000000       9993.000000
# mean           3.958871     301.193836             4.320524        229.852837
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group data by Category and sum the Sales
category_sales = data.groupby('Category')['SalesperCustomer'].sum().reset_index()

# Create bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='SalesperCustomer', data=category_sales)
plt.title('Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()

# %%
# Group data by Country and sum the Sales
country_sales = data.groupby('Country')['SalesperCustomer'].sum()

# Create pie chart
plt.figure(figsize=(10, 6))
country_sales.plot.pie(autopct='%1.1f%%', startangle=140)
plt.title('Sales Distribution by Country')
plt.ylabel('')
plt.show()

# %%
# Create box plot
plt.figure(figsize=(12, 8))
sns.boxplot(x='Sub_Category', y='Profit', data=data)
plt.title('Profit by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.show()

# %%
# Group data by OrderDate and sum the Sales
time_series = data.groupby('OrderDate')['SalesperCustomer'].sum().reset_index()

# Create line plot
plt.figure(figsize=(12, 6))
sns.lineplot(x='OrderDate', y='SalesperCustomer', data=time_series)
plt.title('Sales Trends over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# %%
# Other code for same problem statement

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load Data from Different File Formats
# Load CSV file
sales_csv = pd.read_csv('sales_data.csv')

# Load Excel file
sales_excel = pd.read_excel('sales_data.xlsx')

# Load JSON file
sales_json = pd.read_json('sales_data.json')

# Step 2: Explore Data Structure and Content
# Display first few rows of each dataset
print("CSV Data Sample:\n", sales_csv.head())
print("Excel Data Sample:\n", sales_excel.head())
print("JSON Data Sample:\n", sales_json.head())

# Check for inconsistencies and missing values
print("CSV Missing Values:\n", sales_csv.isnull().sum())
print("Excel Missing Values:\n", sales_excel.isnull().sum())
print("JSON Missing Values:\n", sales_json.isnull().sum())

# Step 3: Data Cleaning
# Handle missing values (e.g., fill or drop them)
sales_csv = sales_csv.fillna(0)
sales_excel = sales_excel.fillna(0)
sales_json = sales_json.fillna(0)

# Remove duplicates
sales_csv.drop_duplicates(inplace=True)
sales_excel.drop_duplicates(inplace=True)
sales_json.drop_duplicates(inplace=True)

# Step 4: Convert Data into a Unified Format
# Standardize column names for merging
sales_csv.columns = sales_csv.columns.str.lower()
sales_excel.columns = sales_excel.columns.str.lower()
sales_json.columns = sales_json.columns.str.lower()

# Combine into a single dataframe
all_sales_data = pd.concat([sales_csv, sales_excel, sales_json], ignore_index=True)

# Step 5: Data Transformation
# Example: Derive new column for 'Order Value' by multiplying quantity by price
all_sales_data['order_value'] = all_sales_data['quantity'] * all_sales_data['price']

# Step 6: Analyze Sales Data
# Descriptive statistics
print(all_sales_data.describe())

# Aggregations
total_sales = all_sales_data['order_value'].sum()
avg_order_value = all_sales_data['order_value'].mean()
product_category_distribution = all_sales_data['product_category'].value_counts()

print("Total Sales:", total_sales)
print("Average Order Value:", avg_order_value)
print("Product Category Distribution:\n", product_category_distribution)

# Step 7: Create Visualizations
# Sales by Product Category
plt.figure(figsize=(10, 6))
sns.barplot(x=product_category_distribution.index, y=product_category_distribution.values)
plt.title("Sales by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.show()

# Pie chart of product category distribution
plt.figure(figsize=(8, 8))
plt.pie(product_category_distribution, labels=product_category_distribution.index, autopct='%1.1f%%')
plt.title("Product Category Distribution")
plt.show()

# Box plot for order values
plt.figure(figsize=(10, 6))
sns.boxplot(data=all_sales_data, y='order_value')
plt.title("Order Value Distribution")
plt.ylabel("Order Value")
plt.show()
